# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.tools import tool

load_dotenv(override=True)

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Invoke list of messages as Conversation

# %%
from langchain.messages import SystemMessage, HumanMessage

groq_model_name = os.getenv("GROQ_MODEL")
groq_model = init_chat_model(
    os.getenv("GROQ_MODEL"),
    model_provider="groq"
)

conversation = [
    SystemMessage("You are a helpful assistant. Don't be rude to the user."),
    HumanMessage("Hello!")
]

groq_model.invoke(conversation)

"""
AIMessage(
    content='Hello! How can I help you today?', 
    additional_kwargs={'reasoning_content': 'The user says "Hello!" The assistant should respond politely.'}, 
    response_metadata={
        'token_usage': {'completion_tokens': 31, 'prompt_tokens': 89, 'total_tokens': 120, 'completion_time': 0.032917105, 'completion_tokens_details': {'reasoning_tokens': 13}, 'prompt_time': 0.005337609, 'prompt_tokens_details': None, 'queue_time': 0.312177188, 'total_time': 0.038254714}, 
        'model_name': 'openai/gpt-oss-20b', 
        'system_fingerprint': 'fp_3023a70d60', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'
    }, 
    id='lc_run--019fb61b-cafa-7750-bbe0-82500e8f8576-0', 
    tool_calls=[], invalid_tool_calls=[], 
    usage_metadata={'input_tokens': 89, 'output_tokens': 31, 'total_tokens': 120, 'output_token_details': {'reasoning': 13}}
)
"""
# Out:
# '\nAIMessage(\n    content=\'Hello! How can I help you today?\', \n    additional_kwargs={\'reasoning_content\': \'The user says "Hello!" The assistant should respond politely.\'}, \n    response_metadata={\n        \'token_usage\': {\'completion_tokens\': 31, \'prompt_tokens\': 89, \'total_tokens\': 120, \'completion_time\': 0.032917105, \'completion_tokens_details\': {\'reasoning_tokens\': 13}, \'prompt_time\': 0.005337609, \'prompt_tokens_details\': None, \'queue_time\': 0.312177188, \'total_time\': 0.038254714}, \n        \'model_name\': \'openai/gpt-oss-20b\', \n        \'system_fingerprint\': \'fp_3023a70d60\', \'service_tier\': \'on_demand\', \'finish_reason\': \'stop\', \'logprobs\': None, \'model_provider\': \'groq\'\n    }, \n    id=\'lc_run--019fb61b-cafa-7750-bbe0-82500e8f8576-0\', \n    tool_calls=[], invalid_tool_calls=[], \n    usage_metadata={\'input_tokens\': 89, \'output_tokens\': 31, \'total_tokens\': 120, \'output_token_details\': {\'reasoning\': 13}}\n)\n'

# %% [markdown]
# - Here you can see that model returns a message of type `AIMessage`.
# - In `reasoning_content` you can see the system prompt that was used to generate the response.
# - The more you define the `SystemMessage`, the better the model will perform.
